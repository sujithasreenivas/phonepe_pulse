# %%
import pandas as pd
import mysql.connector as sql
import streamlit as st
import plotly.express as px
import os
import json
from streamlit_option_menu import option_menu
from PIL import Image

# %%
os.environ["GIT_PYTHON_REFRESH"] = "quiet"
import git
from git.repo.base import Repo
Repo.clone_from("https://github.com/PhonePe/pulse.git", "D:\Capstone\Phonepe1")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\ksree\AppData\Local\Temp\ipykernel_5500\3546484997.py:4: SyntaxWarning: invalid escape sequence '\C'
#   Repo.clone_from("https://github.com/PhonePe/pulse.git", "D:\Capstone\Phonepe1")
# <git.repo.base.Repo 'D:\\Capstone\\Phonepe1\\.git'>

# %%
path1 = "D:/Capstone/Phonepe1/data/aggregated/transaction/country/india/state"
state_list = os.listdir(path1)
print(state_list)
column1 = {'State': [], 'Year': [], 'Quarter': [], 'Transaction_type': [], 'Transaction_count': [],
            'Transaction_amount': []}
for state in state_list:
    cur_state = path1 + "/" +state + "/"
    year_list = os.listdir(cur_state)
   
    for k in year_list:
     cur_year =cur_state+k+"/"
     jstring=os.listdir(cur_year)
    
     for a in jstring:
      curr_data = cur_year+a
    
      data=open(curr_data)
      A=json.load(data)
    
      for i in A['data']['transactionData']:
       name=i['name']
       count=i['paymentInstruments'][0]['count']
       amount=i['paymentInstruments'][0]['amount']
       column1['Transaction_type'].append(name)
       column1['Transaction_amount'].append(amount)
       column1['Transaction_count'].append(count)
       column1['State'].append(state)
       column1['Year'].append(k)
       column1['Quarter'].append(int(a.strip('.json')))
     
df_trans=pd.DataFrame(column1)
df_trans
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...

# %%
df_trans.shape
# Out:
# (4134, 6)

# %%
df_trans.shape
# Out:
# (15, 6)

# %%
df_trans.to_csv("transactiondata.csv", index=False)

# %%
path2 = "D://Capstone//Phonepe1//data//aggregated//user//country//india//state"
state_list1 = os.listdir(path2)
column2 = {'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': []}

for state in state_list1:
    cur_year= path2+"//"+state+"//"
    year_list1=os.listdir(cur_year)
   
    for year in year_list1:
      cur_j= cur_year+year+"//"
      j_list=os.listdir(cur_j)
      
      for jstring in j_list:
       B= cur_j+jstring
       data=open(B,'r')
       B=json.load(data)
      
       try:    
        for j in B["data"]["usersByDevice"]:
          print("j",j)
          brand_name=j['brand']
          count=j['count']
          percentage=j['percentage']
          column2['State'].append(state)
          column2['Year'].append(year)
          column2['Brands'].append(brand_name)
          column2['Count'].append(count)
          column2['Percentage'].append(percentage)
          column2['Quarter'].append(int(jstring.strip('.json')))
       except:
        pass    
df_user=pd.DataFrame(column2)
df_user
# Out:
# j {'brand': 'Xiaomi', 'count': 1665, 'percentage': 0.2470326409495549}
# j {'brand': 'Samsung', 'count': 1445, 'percentage': 0.21439169139465875}
# j {'brand': 'Vivo', 'count': 982, 'percentage': 0.1456973293768546}
# j {'brand': 'Oppo', 'count': 501, 'percentage': 0.07433234421364986}
# j {'brand': 'OnePlus', 'count': 332, 'percentage': 0.04925816023738872}
# j {'brand': 'Realme', 'count': 316, 'percentage': 0.04688427299703264}
# j {'brand': 'Apple', 'count': 229, 'percentage': 0.03397626112759644}
# j {'brand': 'Motorola', 'count': 226, 'percentage': 0.03353115727002967}
# j {'brand': 'Lenovo', 'count': 202, 'percentage': 0.02997032640949555}
# j {'brand': 'Huawei', 'count': 158, 'percentage': 0.02344213649851632}
# j {'brand': 'Others', 'count': 684, 'percentage': 0.10148367952522255}
# j {'brand': 'Xiaomi', 'count': 2303, 'percentage': 0.24486975013290802}
# j {'brand': 'Samsung', 'count': 1923, 'percentage': 0.20446570972886763}
# ...

# %%
df_user.shape
# Out:
# (6732, 6)

# %%
path3 ="D:\\Capstone\\Phonepe1\\data\\map\\transaction\\hover\\country\\india\\state"

map_list=os.listdir(path3)
column3 = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [],
            'Amount': []}

print(map_list)
for state in map_list:
    cur_state1=path3 +"/"+state+"/"
    map_year=os.listdir(cur_state1)
   
    
    for year1 in map_year:
        trans_year=cur_state1+year1+"\\"
        j_year1=os.listdir(trans_year)
        
        
        for jdata in j_year1:
            jstring1=trans_year+jdata
            data=open(jstring1,"r")
            C=json.load(data)
            

            for i in C["data"]["hoverDataList"]:
                District=i["name"]
                count=i["metric"][0]["count"]
                amount=i["metric"][0]["amount"]
                column3['State'].append(state)
                column3['Year'].append(year1)
                column3['District'].append(District)
                column3['Quarter'].append(int(jdata.strip('.json')))
                column3['Count'].append(count)
                column3['Amount'].append(amount)
df_maptrans=pd.DataFrame(column3)
df_maptrans
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16827                west-bengal  2023        3
# 16828                west-bengal  2023        3
# ...

# %%
path4 ="D:\\Capstone\\Phonepe1\\data\\map\\user\\hover\\country\\india\\state"
map_user_list=os.listdir(path4)

columns4 = {"State": [], "Year": [], "Quarter": [], "District": [],
            "RegisteredUser": [], "AppOpens": []}

print(map_user_list)

for state4 in map_user_list:
    cur_state4=path4+ "/" +state4+"/"
    map_year4=os.listdir(cur_state4)


    for year4 in map_year4:
        user_year=cur_state4+year4+"/"
        j_year4=os.listdir(user_year)
        

        for jdata4 in j_year4:
            jstring4=user_year +jdata4
            data=open(jstring4,"r")
            D=json.load(data)
            
            for i in D["data"]["hoverData"].items():
                district = i[0]
                registereduser = i[1]["registeredUsers"]
                appOpens = i[1]['appOpens']
                columns4["District"].append(district)
                columns4["RegisteredUser"].append(registereduser)
                columns4["AppOpens"].append(appOpens)
                columns4['State'].append(state4)
                columns4['Year'].append(year4)
                columns4['Quarter'].append(int(jdata4.strip('.json')))
df_map_user = pd.DataFrame(columns4)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']

# %%
df_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16831                west-bengal  2023        3
# 16832                west-bengal  2023        3
# 16833                west-bengal  2023        3
# 16834                west-bengal  2023        3
# 16835                west-bengal  2023        3
#
#                                 District  RegisteredUser  AppOpens
# 0      north and middle andaman district             632         0
# 1                 south andaman district            5846         0
# 2                      nicobars district             262         0
# 3      north and middle andaman district             911         0
# ...

# %%
path5 ="D:\\Capstone\\Phonepe1\\data\\top\\transaction\\country\\india\\state"
map_top_tlist=os.listdir(path5)
print(map_top_tlist)

columns5 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [],
            'Transaction_amount': []}


for state5 in map_top_tlist:
    cur_state5=path5+ "/" +state5+"/"
    map_year5=os.listdir(cur_state5)
   

    for year5 in map_year5:
        toptrans_year=cur_state5+year5+"/"
        j_year5=os.listdir(toptrans_year)
       

        for jdata5 in j_year5:
            jstring5=toptrans_year + jdata5
            data=open(jstring5,"r")
            E=json.load(data)
            
            for i in E['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns5['Pincode'].append(name)
                columns5['Transaction_count'].append(count)
                columns5['Transaction_amount'].append(amount)
                columns5['State'].append(state)
                columns5['Year'].append(year5)
                columns5['Quarter'].append(int(jdata5.strip('.json')))
df_maptop = pd.DataFrame(columns5)
df_maptop
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 32
#      30 columns5['Transaction_count'].append(count)
#      31 columns5['Transaction_amount'].append(amount)
# ---> 32 columns5['State'].append(state)
#      33 columns5['Year'].append(year5)
#      34 columns5['Quarter'].append(int(jdata5.strip('.json')))
#
# NameError: name 'state' is not defined

# %%
df_maptop
# Out:
#             State  Year  Quarter Pincode  Transaction_count  \
# 0     west-bengal  2018        1  744101               1622
# 1     west-bengal  2018        1  744103               1223
# 2     west-bengal  2018        1  744102                969
# 3     west-bengal  2018        1  744105                685
# 4     west-bengal  2018        1  744104                340
# ...           ...   ...      ...     ...                ...
# 8205  west-bengal  2023        3  700001            3536928
# 8206  west-bengal  2023        3  721301            3464729
# 8207  west-bengal  2023        3  700039            3405551
# 8208  west-bengal  2023        3  732125            3347165
# 8209  west-bengal  2023        3  700015            3304464
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8205        7.193522e+09
# 8206        4.871566e+09
# ...

# %%
path6 = "D:\\Capstone\\Phonepe1\\data\\top\\user\\country\\india\\state"
top_user_list = os.listdir(path6)
columns6 = {'State': [], 'Year': [], 'Quarter': [], 'Pincode': [],
            'RegisteredUsers': []}

for state in top_user_list:
    cur_state = path6 +"/"+ state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            F = json.load(data)
            
            for i in F['data']['pincodes']:
                name = i['name']
                registeredUsers = i['registeredUsers']
                columns6['Pincode'].append(name)
                columns6['RegisteredUsers'].append(registeredUsers)
                columns6['State'].append(state)
                columns6['Year'].append(year)
                columns6['Quarter'].append(int(file.strip('.json')))
df_top_user = pd.DataFrame(columns6)

# %%
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1  744103             1608
# 1     andaman-&-nicobar-islands  2018        1  744101             1108
# 2     andaman-&-nicobar-islands  2018        1  744105             1075
# 3     andaman-&-nicobar-islands  2018        1  744102             1006
# 4     andaman-&-nicobar-islands  2018        1  744104              272
# ...                         ...   ...      ...     ...              ...
# 8206                west-bengal  2023        3  700015           122316
# 8207                west-bengal  2023        3  742304           119245
# 8208                west-bengal  2023        3  721101           118798
# 8209                west-bengal  2023        3  700150           114987
# 8210                west-bengal  2023        3  734006           113991
#
# [8211 rows x 5 columns]

# %%
df_trans.to_csv("aggrtransactiondata.csv", index=False)
df_user.to_csv("aggr_userdata.csv",index=False)
df_top_user.to_csv("top_user.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_trans.to_csv("aggrtransactiondata.csv", index=False)
#       2 df_user.to_csv("aggr_userdata.csv",index=False)
#       3 df_maptrans.to_csv("map_trans.csv",index=False)
#
# NameError: name 'df_trans' is not defined

# %%
df_map_user.to_csv("map_user1.csv",index=False)

# %%
df_maptrans.to_csv("map_trans.csv",index=False)

# %%
df_maptop.to_csv("top_trans.csv",index=False)

# %%
import mysql.connector

# %%
con= mysql.connector.connect(host="localhost",
                            user= "root",
                            password="sujitha@1988",
                            db="phonepe")

# %%
cursor=con.cursor()

# %%
df_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
df_user
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
query="create table aggtransactiondata(State varchar(100),Year int,Quarter int,Transaction_type varchar(150),Transaction_count	int,Transaction_amount int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
query="create table aggr_userdata(State varchar(100),Year int,Quarter int,Brands varchar(150),count int,Percentage int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
df_maptrans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2023        1
# 1      andaman-&-nicobar-islands  2023        1
# 2      andaman-&-nicobar-islands  2023        1
# 3      andaman-&-nicobar-islands  2023        1
# 4      andaman-&-nicobar-islands  2023        1
# ...                          ...   ...      ...
# 19039                west-bengal  2023        3
# 19040                west-bengal  2023        3
# 19041                west-bengal  2023        3
# 19042                west-bengal  2023        3
# 19043                west-bengal  2023        3
#
#                                   District     Count        Amount
# 0      south twenty four parganas district    421793  3.492064e+08
# 1                 purba bardhaman district    396998  2.123560e+08
# 2                  uttar dinajpur district    242526  1.266584e+08
# 3                       kalimpong district      4972  7.706386e+06
# ...

# %%
cursor=con.cursor()
query="create table map_trans(State varchar(100),Year int,Quarter int,District varchar(150),Count int,Amount int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
df_map_user
# Out:
#              State  Year  Quarter                           District  \
# 0      west-bengal  2023        1  north and middle andaman district
# 1      west-bengal  2023        1             south andaman district
# 2      west-bengal  2023        1                  nicobars district
# 3      west-bengal  2023        2  north and middle andaman district
# 4      west-bengal  2023        2             south andaman district
# ...            ...   ...      ...                                ...
# 16831  west-bengal  2023        3                     nadia district
# 16832  west-bengal  2023        3                   birbhum district
# 16833  west-bengal  2023        3           purba medinipur district
# 16834  west-bengal  2023        3                    maldah district
# 16835  west-bengal  2023        3                 darjiling district
#
#        RegisteredUser  AppOpens
# 0                 632         0
# 1                5846         0
# 2                 262         0
# ...

# %%
cursor=con.cursor()
query="create table map_user(State varchar(100),Year int,Quarter int,District varchar(150),RegisteredUser int,AppOpens int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
df_maptop
# Out:
#             State  Year  Quarter Pincode  Transaction_count  \
# 0     west-bengal  2023        1  744101               1622
# 1     west-bengal  2023        1  744103               1223
# 2     west-bengal  2023        1  744102                969
# 3     west-bengal  2023        1  744105                685
# 4     west-bengal  2023        1  744104                340
# ...           ...   ...      ...     ...                ...
# 8205  west-bengal  2023        3  700001            3536928
# 8206  west-bengal  2023        3  721301            3464729
# 8207  west-bengal  2023        3  700039            3405551
# 8208  west-bengal  2023        3  732125            3347165
# 8209  west-bengal  2023        3  700015            3304464
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8205        7.193522e+09
# 8206        4.871566e+09
# ...

# %%
cursor=con.cursor()
query="create table top_trans(State varchar(100),Year int,Quarter int,Pincode int,Transaction_count int,Transaction_amount int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1  744103             1608
# 1     andaman-&-nicobar-islands  2018        1  744101             1108
# 2     andaman-&-nicobar-islands  2018        1  744105             1075
# 3     andaman-&-nicobar-islands  2018        1  744102             1006
# 4     andaman-&-nicobar-islands  2018        1  744104              272
# ...                         ...   ...      ...     ...              ...
# 8206                west-bengal  2023        3  700015           122316
# 8207                west-bengal  2023        3  742304           119245
# 8208                west-bengal  2023        3  721101           118798
# 8209                west-bengal  2023        3  700150           114987
# 8210                west-bengal  2023        3  734006           113991
#
# [8211 rows x 5 columns]

# %%
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1  744103             1608
# 1     andaman-&-nicobar-islands  2018        1  744101             1108
# 2     andaman-&-nicobar-islands  2018        1  744105             1075
# 3     andaman-&-nicobar-islands  2018        1  744102             1006
# 4     andaman-&-nicobar-islands  2018        1  744104              272
# ...                         ...   ...      ...     ...              ...
# 8206                west-bengal  2023        3  700015           122316
# 8207                west-bengal  2023        3  742304           119245
# 8208                west-bengal  2023        3  721101           118798
# 8209                west-bengal  2023        3  700150           114987
# 8210                west-bengal  2023        3  734006           113991
#
# [8211 rows x 5 columns]

# %%
cursor=con.cursor()
query="create table top_user(State varchar(100),Year int,Quarter int,Pincode int,RegisteredUsers int)"
sql=cursor.execute(query)
cursor.close()
# Out:
# True

# %%
State              | varchar(100) | YES  |     | NULL    |       |
| Year               | int          | YES  |     | NULL    |       |
| Quarter            | int          | YES  |     | NULL    |       |
| Transaction_type   | varchar(150) | YES  |     | NULL    |       |
| Transaction_count  | int          | YES  |     | NULL    |       |
| Transaction_amount

# %%
df_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
df_agr_trans= pd.read_csv(r"D:\guvi\python\aggrtransactiondata.csv")
df_agr_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
cursor=con.cursor()
for index,row in df_agr_trans.iterrows():  
  query="""insert into aggtransactiondata(State, Year, Quarter, Transaction_type, Transaction_count, Transaction_amount) values(%s,%s,%s,%s,%s,%s);"""
  
  values=(row['State'],
            row['Year'],
             row['Quarter'],
             row['Transaction_type'],
             row['Transaction_count'],
            row['Transaction_amount']
           )

  cursor.execute(query,values)
 
  con.commit()
cursor.close()
# Out:
# True

# %%
df_agr_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
df_agr_user=pd.read_csv(r"D:\guvi\python\aggr_userdata.csv")
df_agr_user
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
cursor=con.cursor()

for index,row in df_agr_user.iterrows():
    
  query="""insert into aggr_userdata(State, Year, Quarter, Brands,Count,Percentage) values(%s,%s,%s,%s,%s,%s);"""
  
  values=(row['State'],
            row['Year'],
             row['Quarter'],
             row['Brands'],
             row['Count'],
            row['Percentage']
           )

  cursor.execute(query,values)
  
  con.commit()

cursor.close()
# Out:
# True

# %%
df_map_trans=pd.read_csv(r"D:\guvi\python\map_trans.csv")
df_map_trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16827                west-bengal  2023        3
# 16828                west-bengal  2023        3
# 16829                west-bengal  2023        3
# 16830                west-bengal  2023        3
# 16831                west-bengal  2023        3
#
#                                 District     Count        Amount
# 0      north and middle andaman district       442  9.316631e+05
# 1                 south andaman district      5688  1.256025e+07
# 2                      nicobars district       528  1.139849e+06
# 3      north and middle andaman district       825  1.317863e+06
# ...

# %%
cursor=con.cursor()

for index,row in df_map_trans.iterrows():
    
  query="""insert into map_trans(State, Year, Quarter,District,Count,Amount) values(%s,%s,%s,%s,%s,%s);"""
  
  values= (row['State'],
            row['Year'],
             row['Quarter'],
             row['District'],
             row['Count'],
            row['Amount']
           )

  cursor.execute(query,values)
 
  con.commit()
cursor.close()
# Out:
# True

# %%
df_map_user=pd.read_csv(r"D:\guvi\python\map_user.csv")
df_map_user
# Out:
#              State  Year  Quarter                           District  \
# 0      west-bengal  2023        1  north and middle andaman district
# 1      west-bengal  2023        1             south andaman district
# 2      west-bengal  2023        1                  nicobars district
# 3      west-bengal  2023        2  north and middle andaman district
# 4      west-bengal  2023        2             south andaman district
# ...            ...   ...      ...                                ...
# 16831  west-bengal  2023        3                     nadia district
# 16832  west-bengal  2023        3                   birbhum district
# 16833  west-bengal  2023        3           purba medinipur district
# 16834  west-bengal  2023        3                    maldah district
# 16835  west-bengal  2023        3                 darjiling district
#
#        RegisteredUser  AppOpens
# 0                 632         0
# 1                5846         0
# 2                 262         0
# ...

# %%
cursor=con.cursor()

for index,row in df_map_user.iterrows():
    
  query="""insert into map_user(State, Year, Quarter,District,RegisteredUser,AppOpens) values(%s,%s,%s,%s,%s,%s);"""
  
  values= (row['State'],
            row['Year'],
             row['Quarter'],
             row['District'],
             row['RegisteredUser'],
            row['AppOpens']
           )

  cursor.execute(query,values)
  
  con.commit()

cursor.close()
# Out:
# True

# %%
df_top_trans=pd.read_csv(r"D:\guvi\python\top_trans.csv")
df_top_trans
# Out:
#             State  Year  Quarter   Pincode  Transaction_count  \
# 0     west-bengal  2018        1  744101.0               1622
# 1     west-bengal  2018        1  744103.0               1223
# 2     west-bengal  2018        1  744102.0                969
# 3     west-bengal  2018        1  744105.0                685
# 4     west-bengal  2018        1  744104.0                340
# ...           ...   ...      ...       ...                ...
# 8205  west-bengal  2023        3  700001.0            3536928
# 8206  west-bengal  2023        3  721301.0            3464729
# 8207  west-bengal  2023        3  700039.0            3405551
# 8208  west-bengal  2023        3  732125.0            3347165
# 8209  west-bengal  2023        3  700015.0            3304464
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8205        7.193522e+09
# ...

# %%
cursor=con.cursor()

for index,row in df_top_trans.iterrows():
    
 
  query="""insert into top_trans(State,Year,Quarter,Pincode,Transaction_count,Transaction_amount)values(%s,%s,%s,%s,%s,%s);"""
  
  values= (row['State'],
           row['Year'],
           row['Quarter'],
           row['Pincode'],
           row['Transaction_count'],
           row['Transaction_amount']
           )

  cursor.execute(query,values)
  
  con.commit()

cursor.close()
# Out:
# 300 State                 west-bengal
# Year                         2018
# Quarter                         1
# Pincode                  744101.0
# Transaction_count            1622
# Transaction_amount    2769297.904
# Name: 0, dtype: object
# 300 State                    west-bengal
# Year                            2018
# Quarter                            1
# Pincode                     744103.0
# Transaction_count               1223
# Transaction_amount    2238041.871612
# Name: 1, dtype: object
# 300 State                    west-bengal
# Year                            2018
# Quarter                            1
# Pincode                     744102.0
# Transaction_count                969
# Transaction_amount    3519059.937562
# Name: 2, dtype: object
# 300 State                   west-bengal
# Year                           2018
# Quarter                           1
# Pincode                    744105.0
# Transaction_count               685
# ...

# %%
df_top_user=pd.read_csv(r"D:\guvi\python\top_user.csv")
df_top_user
# Out:
#                           State  Year  Quarter  Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1   744103             1608
# 1     andaman-&-nicobar-islands  2018        1   744101             1108
# 2     andaman-&-nicobar-islands  2018        1   744105             1075
# 3     andaman-&-nicobar-islands  2018        1   744102             1006
# 4     andaman-&-nicobar-islands  2018        1   744104              272
# ...                         ...   ...      ...      ...              ...
# 8206                west-bengal  2023        3   700015           122316
# 8207                west-bengal  2023        3   742304           119245
# 8208                west-bengal  2023        3   721101           118798
# 8209                west-bengal  2023        3   700150           114987
# 8210                west-bengal  2023        3   734006           113991
#
# [8211 rows x 5 columns]

# %%
cursor=con.cursor()

for index,row in df_top_user.iterrows():
    
  query="""insert into top_user(State, Year, Quarter,Pincode,RegisteredUsers) values(%s,%s,%s,%s,%s);"""
  
  values= (row['State'],
           row['Year'],
           row['Quarter'],
           row['Pincode'],
           row['RegisteredUsers']
           )

  cursor.execute(query,values)
 
  con.commit()

cursor.close()
# Out:
# 300  State              andaman-&-nicobar-islands
# Year                                    2018
# Quarter                                    1
# Pincode                               744103
# RegisteredUsers                         1608
# Name: 0, dtype: object
# 300  State              andaman-&-nicobar-islands
# Year                                    2018
# Quarter                                    1
# Pincode                               744101
# RegisteredUsers                         1108
# Name: 1, dtype: object
# 300  State              andaman-&-nicobar-islands
# Year                                    2018
# Quarter                                    1
# Pincode                               744105
# RegisteredUsers                         1075
# Name: 2, dtype: object
# 300  State              andaman-&-nicobar-islands
# Year                                    2018
# Quarter                                    1
# Pincode                               744102
# ...
